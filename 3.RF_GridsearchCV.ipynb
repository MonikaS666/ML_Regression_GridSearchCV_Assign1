# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Xtrain=sc.fit_transform(Xtrain)
Xtest=sc.transform(Xtest)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid={"criterion":['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],"max_features":[1.0,2,"sqrt","log2"],'n_estimators':[10,50,80,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,n_jobs=-1,verbose=3)
grid.fit(Xtrain,Ytrain)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# D:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [1.0, 2, 'sqrt', 'log2'],
#                          'n_estimators': [10, 50, 80, 100]},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 50}

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.041975      0.002320         0.005370        0.001045
# 1        0.171075      0.004865         0.007670        0.000775
# 2        0.281454      0.006180         0.010209        0.001296
# 3        0.340445      0.010647         0.012458        0.002184
# 4        0.030712      0.001276         0.004483        0.000696
# ..            ...           ...              ...             ...
# 59       0.966114      0.004771         0.036110        0.001242
# 60       0.104152      0.005190         0.012070        0.004520
# 61       0.491872      0.005373         0.021128        0.003769
# 62       0.686575      0.040788         0.018930        0.003966
# 63       0.749090      0.004984         0.020766        0.003360
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error                1.0                  10
# 1    squared_error                1.0                  50
# 2    squared_error                1.0                  80
# 3    squared_error                1.0                 100
# 4    squared_error                  2                  10
# ..             ...                ...                 ...
# 59         poisson               sqrt                 100
# 60         poisson               log2                  10
# 61         poisson               log2                  50
# 62         poisson               log2                  80
# 63         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.847331
# 1   {'criterion': 'squared_error', 'max_features':...           0.860735
# 2   {'criterion': 'squared_error', 'max_features':...           0.858217
# 3   {'criterion': 'squared_error', 'max_features':...           0.865200
# 4   {'criterion': 'squared_error', 'max_features':...           0.838073
# ..                                                ...                ...
# 59  {'criterion': 'poisson', 'max_features': 'sqrt...           0.864755
# 60  {'criterion': 'poisson', 'max_features': 'log2...           0.837654
# 61  {'criterion': 'poisson', 'max_features': 'log2...           0.854525
# 62  {'criterion': 'poisson', 'max_features': 'log2...           0.862208
# 63  {'criterion': 'poisson', 'max_features': 'log2...           0.862188
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.757157           0.821630           0.774841
# 1            0.762209           0.811965           0.796605
# 2            0.759898           0.811946           0.806517
# 3            0.764214           0.811852           0.806087
# 4            0.777530           0.788296           0.805837
# ..                ...                ...                ...
# 59           0.784283           0.803071           0.828093
# 60           0.777392           0.784035           0.803368
# 61           0.782307           0.802079           0.830418
# 62           0.790981           0.806748           0.828745
# 63           0.798588           0.806226           0.826246
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.772478         0.794687        0.034038               54
# 1            0.768314         0.799966        0.035428               46
# 2            0.771021         0.801520        0.034672               43
# 3            0.771794         0.803829        0.035865               39
# 4            0.756665         0.793280        0.027487               57
# ..                ...              ...             ...              ...
# 59           0.773564         0.810753        0.032740               16
# 60           0.766018         0.793693        0.025104               55
# 61           0.769385         0.807743        0.031155               30
# 62           0.770045         0.811745        0.031719               11
# 63           0.775638         0.813777        0.029125                4
#
# [64 rows x 16 columns]

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 21
# BMI: 25.8
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[2085.519592]
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
