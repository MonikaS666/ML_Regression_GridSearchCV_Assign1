# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Xtrain=sc.fit_transform(Xtrain)
Xtest=sc.transform(Xtest)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid={"criterion":['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],"max_features":[1.0,2,"sqrt","log2"],'n_estimators':[10,50,80,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,n_jobs=-1,verbose=3)
grid.fit(Xtrain,Ytrain)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# D:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [1.0, 2, 'sqrt', 'log2'],
#                          'n_estimators': [10, 50, 80, 100]},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.049847      0.005876         0.003777        0.000628
# 1        0.196490      0.011245         0.009949        0.004764
# 2        0.313197      0.010012         0.011314        0.003424
# 3        0.380965      0.018016         0.013321        0.001349
# 4        0.041461      0.009578         0.004117        0.001137
# ..            ...           ...              ...             ...
# 59       4.615737      0.092019         0.148080        0.014706
# 60       0.502675      0.016224         0.030073        0.018495
# 61       2.318220      0.049545         0.073248        0.025342
# 62       3.195114      0.173691         0.095520        0.011281
# 63       3.299536      0.063031         0.024891        0.005063
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error                1.0                  10
# 1    squared_error                1.0                  50
# 2    squared_error                1.0                  80
# 3    squared_error                1.0                 100
# 4    squared_error                  2                  10
# ..             ...                ...                 ...
# 59         poisson               sqrt                 100
# 60         poisson               log2                  10
# 61         poisson               log2                  50
# 62         poisson               log2                  80
# 63         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.845129
# 1   {'criterion': 'squared_error', 'max_features':...           0.857883
# 2   {'criterion': 'squared_error', 'max_features':...           0.860756
# 3   {'criterion': 'squared_error', 'max_features':...           0.861417
# 4   {'criterion': 'squared_error', 'max_features':...           0.853575
# ..                                                ...                ...
# 59  {'criterion': 'poisson', 'max_features': 'sqrt...           0.867584
# 60  {'criterion': 'poisson', 'max_features': 'log2...           0.812122
# 61  {'criterion': 'poisson', 'max_features': 'log2...           0.858057
# 62  {'criterion': 'poisson', 'max_features': 'log2...           0.863611
# 63  {'criterion': 'poisson', 'max_features': 'log2...           0.867311
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.738294           0.799519           0.790972
# 1            0.764662           0.807576           0.800611
# 2            0.767894           0.820050           0.799151
# 3            0.762086           0.812180           0.799706
# 4            0.776653           0.796039           0.831940
# ..                ...                ...                ...
# 59           0.790288           0.813179           0.831072
# 60           0.778000           0.791916           0.783093
# 61           0.786301           0.798089           0.829033
# 62           0.788445           0.813355           0.827059
# 63           0.782280           0.812301           0.831192
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.762549         0.787293        0.036114               60
# 1            0.769331         0.800013        0.033459               47
# 2            0.767884         0.803147        0.034948               39
# 3            0.766573         0.800392        0.035985               46
# 4            0.743948         0.800431        0.038967               45
# ..                ...              ...             ...              ...
# 59           0.773976         0.815220        0.032619                1
# 60           0.768700         0.786766        0.014739               61
# 61           0.761811         0.806658        0.033590               35
# 62           0.772788         0.813052        0.031557                3
# 63           0.769823         0.812582        0.034895                6
#
# [64 rows x 16 columns]

# %%
from sklearn.metrics import r2_score, mean_squared_error
y_pred = grid.predict(Xtest)
r2 = r2_score(Ytest, y_pred)
mse = mean_squared_error(Ytest, y_pred)
print("R² Score on Test Set:", r2)
print("MSE on Test Set:", mse)
# Out:
# R² Score on Test Set: 0.8707301670434224
# MSE on Test Set: 20614591.116392486

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 21
# BMI: 25.8
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[2085.519592]
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
