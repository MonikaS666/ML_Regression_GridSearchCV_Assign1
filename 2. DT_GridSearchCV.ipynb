# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Xtrain=sc.fit_transform(Xtrain)
Xtest=sc.transform(Xtest)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid={"criterion":['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],"splitter":['best','random'],"max_features":["sqrt","log2"]}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,n_jobs=-1,verbose=3)
grid.fit(Xtrain,Ytrain)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005968      0.001282         0.003431        0.000580
# 1        0.004415      0.001157         0.002990        0.000248
# 2        0.004756      0.000716         0.002323        0.000449
# 3        0.003363      0.000404         0.002536        0.000677
# 4        0.004874      0.001057         0.002894        0.000993
# 5        0.003441      0.001154         0.002819        0.000617
# 6        0.004349      0.000859         0.002745        0.001411
# 7        0.003367      0.001032         0.001986        0.000946
# 8        0.013371      0.001723         0.002007        0.000280
# 9        0.011301      0.001348         0.002363        0.000841
# 10       0.012332      0.000709         0.001998        0.000026
# 11       0.009281      0.002794         0.002243        0.001789
# 12       0.006747      0.001445         0.002008        0.000897
# 13       0.004424      0.001024         0.001614        0.000807
# 14       0.004076      0.001852         0.001788        0.002436
# 15       0.006713      0.001112         0.002225        0.001112
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.736654
# 1   {'criterion': 'squared_error', 'max_features':...           0.519729
# 2   {'criterion': 'squared_error', 'max_features':...           0.176079
# 3   {'criterion': 'squared_error', 'max_features':...           0.685056
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.685721
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.632842
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.701708
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.643954
# 8   {'criterion': 'absolute_error', 'max_features'...           0.715612
# 9   {'criterion': 'absolute_error', 'max_features'...           0.560690
# 10  {'criterion': 'absolute_error', 'max_features'...           0.564268
# 11  {'criterion': 'absolute_error', 'max_features'...           0.742815
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.607805
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.480395
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.666396
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.659228
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.648355           0.664061           0.677899
# 1            0.626246           0.654413           0.603368
# 2            0.527664           0.657094           0.654733
# 3            0.547340           0.659051           0.599971
# 4            0.605463           0.571052           0.686659
# 5            0.579179           0.486889           0.613110
# 6            0.615121           0.674693           0.472851
# 7            0.476031           0.421650           0.527956
# 8            0.630312           0.658998           0.657020
# 9            0.594976           0.654047           0.603307
# 10           0.691057           0.555990           0.647426
# 11           0.516471           0.425701           0.485679
# 12           0.387099           0.725778           0.663248
# 13           0.632011           0.531974           0.543114
# 14           0.595667           0.570996           0.537509
# 15           0.622999           0.572351           0.606600
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.617121         0.668818        0.039492                1
# 1            0.634551         0.607661        0.046914                8
# 2            0.626997         0.528513        0.182414               14
# 3            0.537479         0.605779        0.058714                9
# 4            0.628128         0.635405        0.045276                3
# 5            0.550780         0.572560        0.051256               11
# 6            0.618281         0.616531        0.079104                5
# 7            0.528759         0.519670        0.073634               16
# 8            0.604744         0.653337        0.036919                2
# 9            0.703508         0.623306        0.050001                4
# 10           0.546387         0.601026        0.057660               10
# 11           0.495775         0.533288        0.109026               13
# 12           0.226294         0.522045        0.186804               15
# 13           0.572873         0.552074        0.049889               12
# 14           0.677077         0.609529        0.054149                7
# 15           0.609871         0.614210        0.028046                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 21
# BMI: 25.800
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16085.1275]
